# %% [markdown]
# # Actividad esfera de Bloch

# %% [markdown]
# ## 0. Importación de librerias

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

import math 
import Operaciones_v14 as op
# %matplotlib notebook

# %% [markdown]
# ## 1. Gráfica de una esfera, un punto, una flecha y como hacer una etiqueta
#
# El siguiente codigo grafica una esfera que representa el planeta Tierra, y en esta se grafican distintas ciudades.

# %%
Ciudades = [
    ['Londres', 51.5, -0.1167],
    ['Bogotá', 4.5964, -74.0833],
    ['Roma', 41.8960, 12.4833],
    ['Melbourne', -37.8200, 144.9750],
    ['Nairobi', -1.2833, 36.8167],
    ['Santiago', -33.4500, -70.6670],
    ['Nueva York', 40.6943, -73.9249],
    ['Los Angeles', 34.1139, -118.4068],
    ['Moscú', 55.7522, 37.6155],
    ['Quito', -0.2150, -78.5001],
    ['Tokio', 35.6850, 139.7514],
    ['Lagos', 6.4433, 3.3915],
    ['Atenas', 37.9833, 23.7333],
    ['Belén de Pará', -1.4500, -48.4800],
    ['Budapest', 47.5000, 19.0833],
    ['Vancouver', 49.2734, -123.1216],
    ['París', 48.8667, 2.3333],
    ['Puebla', 19.0500, -98.2000],
    ['Berna', 46.9480900, 7.4474400]
]
Lat = []
Lon = []
Ciud = []
for g in range(len(Ciudades)):
    Lat.append(Ciudades[g][1])
    Lon.append(Ciudades[g][2])
    Ciud.append(Ciudades[g][0])
L = []
Lo = []
for i in range(len(Lat)):
    L.append((np.pi/2) - (Lat[i] * np.pi/180))
    Lo.append((Lon[i] * np.pi/180))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

phi, theta = np.mgrid[0 : 2 * np.pi : 0.1, 0 : np.pi : 0.1]  # Equivale a hacer un doble for


# Para pasar de coordenadas esféricas (phi, theta) a coordenadas cartesianas (x, y, z):

x = np.cos(phi) * np.sin(theta)
y = np.sin(phi) * np.sin(theta)
z = np.cos(theta)

# Para graficar la esfera (estructura de alambre):

ax.plot_wireframe(x, y, z, color='green', rstride=2, cstride=2, linewidth=0.5, alpha=0.8)

# Para graficar un punto cualquiera en el espacio 3d, en este caso (2, -2, 1):
for t in range(len(L)):
    ax.scatter(np.cos(Lo[t]) * np.sin(L[t]), np.sin(Lo[t]) * np.sin(L[t]), np.cos(L[t]), color='red', s=10) # El valor de s modifica el grosor del punto

# Para hacer una etiqueta, en este caso sobre el punto (2, -2, 1):
for u in range(len(L)):
    ax.text(np.cos(Lo[u]) * np.sin(L[u]), np.sin(Lo[u]) * np.sin(L[u]), np.cos(L[u]), Ciud[u], color='black')


# Para graficar una flecha, en este caso del origen al punto (2, -2, 1):
print(len(L))
for p in range(len(L)):
    ax.quiver(0, 0, 0, np.cos(Lo[p]) * np.sin(L[p]), np.sin(Lo[p]) * np.sin(L[p]), np.cos(L[p]), color='blue')


# Nombres de los ejes

ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# 19

# %% [markdown]
# ## La esfera de Bloch
#
# La siguiente función grafica una esfera, y en esta se grafican distintos Kets Basicos

# %%
def main():
    L = [poli([1,0],[0,0])[0], poli([0,0],[1,0])[0], poli([1/np.sqrt(2),0],[0,1/np.sqrt(2)])[0], poli([0,1/np.sqrt(2)],[1/np.sqrt(2),0])[0], poli([1/np.sqrt(2),0],[1/np.sqrt(2),0])[0], poli([1/np.sqrt(2),0],[-1/np.sqrt(2),0])[0]]
    Lo = [poli([1,0],[0,0])[1], poli([0,0],[1,0])[1], poli([1/np.sqrt(2),0],[0,1/np.sqrt(2)])[1], poli([0,1/np.sqrt(2)],[1/np.sqrt(2),0])[1], poli([1/np.sqrt(2),0],[1/np.sqrt(2),0])[1], poli([1/np.sqrt(2),0],[-1/np.sqrt(2),0])[1]]
    Ciud = ["0", "1", "in", "out", "+" , "-"]
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    phi, theta = np.mgrid[0 : 2 * np.pi : 0.1, 0 : np.pi : 0.1]  # Equivale a hacer un doble for
    # Para pasar de coordenadas esféricas (phi, theta) a coordenadas cartesianas (x, y, z):

    x = np.cos(phi) * np.sin(theta)
    y = np.sin(phi) * np.sin(theta)
    z = np.cos(theta)

    # Para graficar la esfera (estructura de alambre):

    ax.plot_wireframe(x, y, z, color='green', rstride=2, cstride=2, linewidth=0.5, alpha=0.8)

    # Para graficar un punto cualquiera en el espacio 3d, en este caso (2, -2, 1):
    for t in range(len(L)):
        ax.scatter(np.cos(Lo[t]) * np.sin(L[t]), np.sin(Lo[t]) * np.sin(L[t]), np.cos(L[t]), color='red', s=10) # El valor de s modifica el grosor del punto

    # Para hacer una etiqueta, en este caso sobre el punto (2, -2, 1):
    for u in range(len(L)):
        ax.text(np.cos(Lo[u]) * np.sin(L[u]), np.sin(Lo[u]) * np.sin(L[u]), np.cos(L[u]), Ciud[u], color='black')


    # Para graficar una flecha, en este caso del origen al punto (2, -2, 1):
    print("len", len(L))
    for p in range(len(L)):
        ax.quiver(0, 0, 0, np.cos(Lo[p]) * np.sin(L[p]), np.sin(Lo[p]) * np.sin(L[p]), np.cos(L[p]), color='blue')


    # Nombres de los ejes

    ax.set_xlabel('Eje X')
    ax.set_ylabel('Eje Y')
    ax.set_zlabel('Eje Z')

    plt.show()


def poli(ket_1, ket_2):
    #ket_1 = [3, 2]
    #ket_2 = [2, 4]
    r1 = op.pol(ket_1)
    r2 = op.pol(ket_2)
    #print("r1 r2",ket_1, r1, ket_2, r2)
    par_2 = r1[1] + r2[1]
    par_2 = par_2 * np.pi/180
    print("par2", par_2, ket_1, ket_2)
    par_1v1 = math.atan(r1[0]) 
    print("par1", par_1v1, "r1", r1, "r2", r2)
    #par_1v2 = math.cos(par_1v1) + math.sin(par_1v1)
    return [par_1v1, par_2]
    #return [r1[0], r1[1]]
    #print("par 1 = " + "cos(" + str(round(par_1v1, 3)) + ")" + " sin(" + str(round(par_1v1, 3)) + ")")
    #print("par 2 = " + str(round(par_2, 3)))

main()
# Out:
# par2 0.0 [1, 0] [0, 0]
# par1 0.7853981633974483 r1 [1.0, 0.0] r2 [0.0, 0.0]
# par2 0.0 [0, 0] [1, 0]
# par1 0.0 r1 [0.0, 0.0] r2 [1.0, 0.0]
# par2 0.02741556778080377 [0.7071067811865475, 0] [0, 0.7071067811865475]
# par1 0.6154797086703873 r1 [0.7071067811865475, 0.0] r2 [0.7071067811865475, 1.5707963267948966]
# par2 0.02741556778080377 [0, 0.7071067811865475] [0.7071067811865475, 0]
# par1 0.6154797086703873 r1 [0.7071067811865475, 1.5707963267948966] r2 [0.7071067811865475, 0.0]
# par2 0.0 [0.7071067811865475, 0] [0.7071067811865475, 0]
# par1 0.6154797086703873 r1 [0.7071067811865475, 0.0] r2 [0.7071067811865475, 0.0]
# par2 0.05483113556160754 [0.7071067811865475, 0] [-0.7071067811865475, 0]
# par1 0.6154797086703873 r1 [0.7071067811865475, 0.0] r2 [0.7071067811865475, 3.141592653589793]
# par2 0.0 [1, 0] [0, 0]
# par1 0.7853981633974483 r1 [1.0, 0.0] r2 [0.0, 0.0]
# par2 0.0 [0, 0] [1, 0]
# par1 0.0 r1 [0.0, 0.0] r2 [1.0, 0.0]
# ...
